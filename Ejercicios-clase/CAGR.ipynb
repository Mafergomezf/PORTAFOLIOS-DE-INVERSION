# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
prices = yf.download(['WMT','NVDA'], start='2020-01-01', end='2026-09-07')['Close']
# Out:
# /var/folders/x9/60hcc2ln62d3r3xyv90d3wl40000gn/T/ipykernel_6016/1700523590.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   prices = yf.download(['WMT','NVDA'], start='2020-01-01', end='2026-09-07')['Close']
# [*********************100%***********************]  2 of 2 completed

# %%
rets=(prices/prices.shift()-1).dropna()
rets
# Out:
# Ticker          NVDA       WMT
# Date
# 2020-01-03 -0.016006 -0.008828
# 2020-01-06  0.004194 -0.002036
# 2020-01-07  0.012106 -0.009265
# 2020-01-08  0.001875 -0.003432
# 2020-01-09  0.010983  0.010331
# ...              ...       ...
# 2026-08-31  0.014847  0.017267
# 2026-09-01 -0.015128  0.010012
# 2026-09-02  0.032055  0.001605
# 2026-09-03  0.018003  0.021963
# 2026-09-04  0.008361 -0.011806
#
# [1677 rows x 2 columns]

# %%
#Rend esperado
rets.mean()*252*100
# Out:
# Ticker
# NVDA    68.354186
# WMT     19.078705
# dtype: float64

# %%
#Media Geometrica CAGR
#CAGR=
(((rets+1).prod())**(1/len(rets))-1)*252*100
# Out:
# Ticker
# NVDA    54.966935
# WMT     16.309186
# dtype: float64
